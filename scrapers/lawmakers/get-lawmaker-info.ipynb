# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import codecs
import json
import base64
from PIL import Image
from io import BytesIO

# %%
NAME_CLEANING = {
    # 2019 legislature w/ late-term replacements
    'Kim Abbott': 'Kim Abbott',
    'Fred Anderson': 'Fred Anderson',
    'Duane Ankney': 'Duane Ankney',
    'JACOB BACHMEIER': 'Jacob Bachmeier',
    'JADE BAHR': 'Jade Bahr',
    'NANCY BALLANCE': 'Nancy Ballance',
    'DICK BARRETT': 'Dick Barrett',
    'Dan Bartel': 'Dan Bartel',
    'Becky Beard': 'Becky Beard',
    'David Bedey': 'David Bedey',
    'Bryce Bennett': 'Bryce Bennett',
    'Seth Berglee': 'Seth Berglee',
    'BARBARA BESSETTE': 'Barbara Bessette',
    'Laurie Bishop': 'Laurie Bishop',
    'Mark Blasdel': 'Mark Blasdel',
    'Kenneth Bogner': 'Kenneth Bogner',
    'Cydnie ': 'Carlie Boland',
    'Larry Brewster': 'Larry Brewster',
    'ZACH BROWN': 'Zach Brown',
    'DEE BROWN': 'Dee Brown',
    'Bob Brown': 'Bob Brown',
    'TOM BURNETT': 'Tom Burnett',
    'Ed Buttrey': 'Ed Buttrey',
    'Mary Caferro': 'Mary Caferro',
    'Jill Cohenour': 'Jill Cohenour',
    'Mike Cuffe': 'Mike Cuffe',
    'Willis Curdy': 'Willis Curdy',
    'Geraldine Custer': 'Geraldine Custer',
    'GREG DEVRIES': 'Greg DeVries',
    'ALAN DOANE': 'Alan Doane',
    'Julie Dooling': 'Julie Dooling',
    'KIMBERLY DUDIK': 'Kim Dudik',
    'DAVID DUNN': 'David Dunn',
    'Mary Ann Dunwell': 'Mary Ann Dunwell',
    'Neil Duram': 'Neil Duram',
    'Janet Ellis': 'Janet Ellis',
    'Jason Ellsworth': 'Jason Ellsworth',
    'John Esp': 'John Esp',
    'Robert Farris': 'Robert Farris-Olsen',
    'Dave Fern': 'Dave Fern',
    'JENNIFER FIELDER': 'Jennifer Fielder',
    'Ross Fitzgerald': 'Ross Fitzgerald',
    'Steve Fitzpatrick': 'Steve Fitzpatrick',
    'Frank Fleming': 'Frank Fleming',
    'Pat Flowers': 'Pat Flowers',
    'John Fuller': 'John Fuller',
    'Moffie Funk': 'Moffie Funk',
    'Wylie Galt': 'Wylie Galt',
    'RODNEY GARCIA': 'Rodney Garcia',
    'Frank Garner': 'Frank Garner',
    'Terry Gauthier': 'Terry Gauthier',
    'Bruce ': 'Bruce Gillespie',
    'Carl Glimm': 'Carl Glimm',
    'Sharon Greef': 'Sharon Greef',
    'Jen Gross': 'Jen Gross',
    'BRUCE GRUBBS': 'Bruce Grubbs',
    'Steve Gunderson': 'Steve Gunderson',
    'Jim Hamilton': 'Jim Hamilton',
    'BRADLEY MAXON HAMLETT': 'Bradley Hamlett',
    'Derek Harvey': 'Derek Harvey',
    'Denise Hayman': 'Denise Hayman',
    'Greg Hertz': 'Greg Hertz',
    'Steve Hinebauch': 'Steve Hinebauch',
    'Kenneth Holmlund': 'Kenneth Holmlund',
    'Mike Hopkins': 'Mike Hopkins',
    'Brian Hoven': 'Brian Hoven',
    'David Howard': 'David Howard',
    'Tom Jacobson': 'Tom Jacobson',
    'Llew Jones': 'Llew Jones',
    'Jessica Karjala': 'Jessica Karjala',
    'Doug Kary': 'Doug Kary',
    'Josh Kassmier': 'Josh Kassmier',
    'Jim Keane': 'Jim Keane',
    'Bob Keenan': 'Bob Keenan',
    'Kathy Kelker': 'Kathy Kelker',
    'Connie Keogh': 'Connie Keogh',
    'Emma Kerr': 'Emma Kerr-Carpenter',
    'Casey Knudsen': 'Casey Knudsen',
    'Rhonda Knudsen': 'Rhonda Knudsen',
    'JOEL KRAUTTER': 'Joel Krautter',
    'JASMINE KROTKOV': 'Jasmine Krotkov',
    'Mike Lang': 'Mike Lang',
    'Dennis Lenz': 'Dennis Lenz',
    'Denley Loge': 'Denley Loge',
    'Ryan Lynch': 'Ryan Lynch',
    'MARGARET ': 'Margie MacDonald',
    'SUE MALEK': 'Sue Malek',
    'FORREST MANDEVILLE': 'Forrest Mandeville',
    'Theresa Manzella': 'Theresa Manzella',
    'Marilyn Marler': 'Marilyn Marler',
    'Edie McClafferty': 'Edie McClafferty',
    'Edie Mcclafferty':'Edie McClafferty',
    'NATE MCCONNELL': 'Nate McConnell',
    'Wendy McKamey': 'Wendy McKamey',
    'Wendy Mckamey': 'Wendy McKamey',
    'Mary McNally': 'Mary McNally',
    'Mary Mcnally': 'Mary McNally',
    'Bill Mercer': 'Bill Mercer',
    'Terry Moore': 'Terry Moore',
    'FREDERICK ': 'Eric Moore',
    'Shane Morigeau': 'Shane Morigeau',
    'DALE MORTENSEN': 'Dale Mortensen',
    'Mark Noland': 'Mark Noland',
    'Andrea Olsen': 'Andrea Olsen',
    'ALBERT OLSZEWSKI': 'Albert Olszewski',
    'Ryan Osmundson': 'Ryan Osmundson',
    'RAE PEPPERS': 'Rae Peppers',
    'ZAC PERRY': 'Zac Perry',
    'MIKE PHILLIPS': 'Mike Phillips',
    'GORDON PIERSON': 'Gordon Pierson',
    'JP Pomnichowski': 'JP Pomnichowski',
    'Jp Pomnichowski': 'JP Pomnichowski',
    'Christopher Pope': 'Chris Pope',
    'DEBO POWERS': 'Debo Powers',
    'Joe Read': 'Joe Read',
    'ALAN REDFIELD': 'Alan Redfield',
    'Matt Regier': 'Matt Regier',
    'Keith Regier': 'Keith Regier',
    'Vince Ricci': 'Vince Ricci',
    'TOM RICHMOND': 'Tom Richmond',
    'Tyson Running Wolf': 'Tyson Running Wolf',
    'MARILYN RYAN': 'Marilyn Ryan',
    'Walt Sales': 'Walt Sales',
    'SCOTT SALES': 'Scott Sales',
    'Dan Salomon': 'Dan Salomon',
    'Diane Sands': 'Diane Sands',
    'CASEY SCHREINER': 'Casey Schreiner',
    'JON SESSO': 'Jon Sesso',
    'RAY SHAW': 'Ray Shaw',
    'Lola Sheldon': 'Lola Sheldon-Galloway',
    'Derek Skees': 'Derek Skees',
    'Jason Small': 'Jason Small',
    'Frank Smith': 'Frank Smith',
    'Cary Smith': 'Cary Smith',
    'BRIDGET SMITH': 'Bridget Smith',
    'Sharon Stewart Peregoy': 'Sharon Stewart Peregoy',
    'Katie Sullivan': 'Katie Sullivan',
    'Mark Sweeney': 'Mark Sweeney',
    'Russ Tempel': 'Russ Tempel',
    'FRED THOMAS': 'Fred Thomas',
    'Brad Tschida': 'Brad Tschida',
    'Barry Usher': 'Barry Usher',
    'Gordon Vance': 'Gordon Vance',
    'Sue Vinton': 'Sue Vinton',
    'GENE VUCKOVICH': 'Gene Vuckovich',
    'Marvin Weatherwax': 'Marvin Weatherwax',
    'ROGER WEBB': 'Roger Webb',
    'PEGGY WEBB': 'Peggy Webb',
    'Susan Webber': 'Susan Webber',
    'Jeff Welborn': 'Jeff Welborn',
    'Tom Welch': 'Tom Welch',
    'KERRY WHITE': 'Kerry White',
    'Jonathan Windy Boy': 'Jonathan Windy Boy',
    'TOM WINTER': 'Tom Winter',
    'TOM WOODS': 'Tom Woods',
    'DANIEL ZOLNIKOV': 'Daniel Zolnikov',
    'Katie Zolnikov': 'Katie Zolnikov',
    'Fiona Nave': 'Fiona Nave',
    
    # New for 20201 legislature
    'Marta Bertoglio': 'Marta Bertoglio',
    'Michele Binkley': 'Michele Binkley',
    'Ellie Boldman': 'Ellie Boldman',
    'Alice Buckley': 'Alice Buckley',
    'Jennifer Carlson': 'Jennifer Carlson',
    'Paul Fielder': 'Paul Fielder',
    'Mike Fox': 'Mike Fox',
    'Tom France': 'Tom France',
    'Gregory Frazer': 'Gregory Frazer',
    'Chris Friedel': 'Chris Friedel',
    'Steven Galloway': 'Steven Galloway',
    'Jane Gillette': 'Jane Gillette',
    'Steve Gist': 'Steve Gist',
    'Donavon Hawk': 'Donavon Hawk',
    'Ed Hill': 'Ed Hill',
    'Jedediah Hinkle': 'Jedediah Hinkle',
    'Caleb Hinkle': 'Caleb Hinkle',
    'Scot Kerns': 'Scot Kerns',
    'Kelly Kortum': 'Kelly Kortum',
    'Brandon Ler': 'Brandon Ler',
    'Marty Malone': 'Marty Malone',
    'Ron Marshall': 'Ron Marshall',
    'Tom McGillvray': 'Tom McGillvray',
    'Tom Mcgillvray': 'Tom McGillvray',
    'Braxton Mitchell': 'Braxton Mitchell',
    'Brad Molnar': 'Brad Molnar',
    'Fiona  Nave': 'Fiona  Nave',
    'Sara Novak': 'Sara Novak',
    'Shannon O': "Shannon O'Brien",
    'Jimmy Patelis':  'Jimmy Patelis',
    'Bob Phalen':  'Bob Phalen',
    'Brian Putnam': 'Brian Putnam',
    'Amy Regier': 'Amy Regier',
    "Linda Reksten":  "Linda Reksten",
    "Jerry Schillinger": "Jerry Schillinger",
    "Kerri Seekins": "Kerri Seekins-Crowe",
    "Ed Stafman": "Ed Stafman",
    "Mallerie Stromswold": "Mallerie Stromswold",
    "Danny Tenenbaum":  "Danny Tenenbaum",
    "Mark Thane":  "Mark Thane",
    "Jeremy Trebas": "Jeremy Trebas",
    "Kenneth Walsh": 'Kenneth Walsh',
    'Rynalea Whiteman Pena': 'Rynalea Whiteman Pena',
    'Kathy Whitman': 'Kathy Whitman',
}

def get_name(page):
    title = page.find('h3').text
    name = re.search(r'(?<=(Sen|Rep)\. )(\w| )+', title).group(0)
    name = name.replace('  ',' ').title()
#     if name not in NAME_CLEANING.keys():
#         print(f'No Match: "{name}"')
#         return name
    cleaned = NAME_CLEANING[name]
    return cleaned

def get_district(page):
    title = page.find('h3').text
    district = re.search(r'(SD|HD)\w+', title).group(0)
    district = district.replace('SD','SD ').replace('HD','HD ')
    return district

def get_address(page):
    address = page.find(string="Address").parent.text
    address = re.sub(r'\n\s+',' ', address)
    address = re.sub(r'\s+',' ', address)
    address = address.replace('Address ','')
    return address.strip(' ')


    

def get_city(page):
    address = page.find(string="Address").parent.text
    city = re.search(r'(?<=\n)(\w| )+(?=, MT)', address).group(0)
    return city.strip().title()

def get_sessions_served(page):
    table = page.find('strong', string='Legislative Service').parent.findNext('p')
    try:
        house_text = re.search('(?<=House:)\s+(.|\n)+?(?=<br/>|</p>)', str(table)).group(0)
    except AttributeError:
        house_text = ''
    house_session_links = BeautifulSoup(house_text, 'html.parser')

    try:
        senate_text = re.search('(?<=Senate:)\s+(.|\n)+?(?=<br/>|</p>)', str(table)).group(0)
    except AttributeError:
        senate_text = ''
    senate_session_links = BeautifulSoup(senate_text, 'html.parser')

    sessions = []
    for link in house_session_links.find_all(True):
        sessions.append({
            'year': link.text ,
            'url': f'https://leg.mt.gov/{link["href"]}',
            'chamber': 'house',
        })
    for link in senate_session_links.find_all(True):
        sessions.append({
            'year': link.text ,
            'url': f'https://leg.mt.gov/{link["href"]}',
            'chamber': 'senate',
        })
    return sessions

def get_committees(page_soup):
    assignment_table = page_soup.find(id='committeeAssignmentTable').find('tbody')
    rows = assignment_table.find_all('tr')
    
    committees = []
    for row in rows:
        cols = row.find_all('td')
        committee = re.search(r'\((S|H|J)\).+', cols[0].text).group(0).replace('(S)','Senate').replace('(H)', 'House').replace('(J)', 'Joint')
        role = re.search(r'(Member|Chair|Vice Chair|Majority Vice Chair|Minority Vice Chair|NULL)', cols[1].text).group(0).replace('NULL','Member')
        committees.append({
            'committee': committee,
            'role': role,
        })
    return committees

def download_portrait(page, path):
    portrait = page.find('img')
    src = portrait['src'].split(',')[1]
    im = Image.open(BytesIO(base64.b64decode(src)))
    im.save(path, 'PNG')
    print('--Image written to', path)

# %%
def get_roster(file):
    # Fetch list of names
    # HTML downloaded from https://leg.mt.gov/legislator-information/

    roster_html = codecs.open(file,'r').read()
    roster_soup = BeautifulSoup(roster_html, 'html.parser')
    rows = list(roster_soup.find('table', id='reports-table').find_all('tr'))
    headers = rows[0]
    rows = rows[1:]
    roster = []
    for row in rows:
        url = row.find('td', {"class":'nameCell'}).find('a')['href']
        name_text = row.find('td', {"class":'nameCell'}).text.strip().replace('\n                       ','').split(' \n                    \n')
        if len(name_text) > 1: note = name_text[1]
        else: note = ''
        #     email_url = row.find('td', {"class":'emailCell'}).find('a')['href']

        roster.append({
            'name': name_text[0],
            'party': row.find('td', {"class":'partyCell'}).text.strip().replace('\n                       ',''),
            'district': row.find('td', {"class":'seatCell'}).text.strip().replace('\n                    ',' '),
    #         'email': email_url,
            'phone': row.find('td', {"class":'phoneCell'}).text.strip().replace('\n                    ',', '),
            'url': f'https://leg.mt.gov/{url}',
            'note': note,
        })
    return roster
    

def get_lawmaker(lawmaker, fetch_portraits=True):
    print('Fetching', lawmaker['name'], lawmaker['url'])
    session = requests.Session()
    r = session.get(lawmaker['url'])
    page = BeautifulSoup(r.text, 'html.parser')
    
    name = get_name(page)
    key = name.replace(' ','-')
    image_path = f'images/{key}-{year}.png'
    
    download_portrait(page, image_path) # Slow
    
    results = {
        'name': name,
        'district': get_district(page),
        'party': lawmaker['party'],
        'address': get_address(page),
        'city': get_city(page),
        'sessions': get_sessions_served(page),
        'committees_19': get_committees(page),
        'note': lawmaker['note'],
        'image_path': image_path,
        'source': lawmaker['url'],
    }
    return results

# %%
roster = get_roster('raw/web-roster-2021.html')

# %%
# Duane Ankney
# url = 'https://leg.mt.gov/legislator-information/roster/individual/5044' # Ankney
# url = 'https://leg.mt.gov/legislator-information/roster/individual/5139' # Beard
# url = 'https://leg.mt.gov//legislator-information/roster/individual/5087' # Bachmeier
url = 'https://leg.mt.gov/legislator-information/roster/individual/6872'
session = requests.Session()
r = session.get(url)
test_page = BeautifulSoup(r.text, 'html.parser')
get_name(test_page)
# get_city(test_page)
# Out:
# 'Kim Abbott'

# %%
# Second pass info
def get_phone(page):
    line = page.find(string=re.compile(r"Primary ph:"))
    phone = line.replace('Primary ph: ','')
    return phone
    
def get_email(page):
    line = page.find(string=re.compile(r"Email:"))
    email = line.replace('Email: ','').strip()
    return email
# Out:
# 'kim.abbott@mtleg.gov'

# %%
# Supplemental info pass
year = '2021'
contact = []
for lawmaker in roster:
    print('Fetching', lawmaker['name'], lawmaker['url'])
    session = requests.Session()
    r = session.get(lawmaker['url'])
    page = BeautifulSoup(r.text, 'html.parser')
    
    name = get_name(page)
    phone = get_phone(page)
    email = get_email(page)
    
    
    results = {
        'name': name,
        'phone': phone,
        'email': email,
    }
    contact.append(results)
    
with open('process/contact-info.json', 'w') as f:
    stringed = json.dumps(contact, indent=4)
    f.write(stringed)
    print('File written')
# Out:
# Fetching Kim  Abbott https://leg.mt.gov//legislator-information/roster/individual/6872
# Fetching Fred  Anderson https://leg.mt.gov//legislator-information/roster/individual/6898
# Fetching Duane  Ankney https://leg.mt.gov//legislator-information/roster/individual/6810
# Fetching Dan  Bartel https://leg.mt.gov//legislator-information/roster/individual/6839
# Fetching Becky  Beard https://leg.mt.gov//legislator-information/roster/individual/6924
# Fetching David  Bedey https://leg.mt.gov//legislator-information/roster/individual/6854
# Fetching Bryce  Bennett https://leg.mt.gov//legislator-information/roster/individual/6802
# Fetching Seth  Berglee https://leg.mt.gov//legislator-information/roster/individual/6916
# Fetching Marta  Bertoglio https://leg.mt.gov//legislator-information/roster/individual/6922
# Fetching Derek  Skees https://leg.mt.gov//legislator-information/roster/individual/6835
# Fetching Jason  Small https://leg.mt.gov//legislator-information/roster/individual/6935
# Fetching Cary  Smith https://leg.mt.gov//legislator-information/roster/individual/6812
# Fetching Frank  Smith https://leg.mt.gov//legislator-information/roster/individual/6827
# Fetching Ed  Stafman https://leg.mt.gov//legislator-information/roster/individual/6862
# Fetching Sharon  Stewart Peregoy https://leg.mt.gov//legislator-information/roster/individual/6829
# Fetching Mallerie  Stromswold https://leg.mt.gov//legislator-information/roster/individual/6912
# Fetching Katie  Sullivan https://leg.mt.gov//legislator-information/roster/individual/6874
# Fetching Mark  Sweeney https://leg.mt.gov//legislator-information/roster/individual/6885
# Fetching Russ  Tempel https://leg.mt.gov//legislator-information/roster/individual/6808
# Fetching Danny  Tenenbaum https://leg.mt.gov//legislator-information/roster/individual/6878
# Fetching Mark  Thane https://leg.mt.gov//legislator-information/roster/individual/6880
# Fetching Jeremy  Trebas https://leg.mt.gov//legislator-information/roster/individual/6904
# Fetching Brad  Tschida https://leg.mt.gov//legislator-information/roster/individual/6930
# Fetching Barry  Usher https://leg.mt.gov//legislator-information/roster/individual/6908
# Fetching Gordon  Vance https://leg.mt.gov//legislator-information/roster/individual/6815
# Fetching Sue  Vinton https://leg.mt.gov//legislator-information/roster/individual/6849
# Fetching Kenneth  Walsh https://leg.mt.gov//legislator-information/roster/individual/6921
# Fetching Marvin  Weatherwax https://leg.mt.gov//legislator-information/roster/individual/6825
# Fetching Susan  Webber https://leg.mt.gov//legislator-information/roster/individual/6793
# Fetching Jeff  Welborn https://leg.mt.gov//legislator-information/roster/individual/6937
# Fetching Tom  Welch https://leg.mt.gov//legislator-information/roster/individual/6853
# Fetching Rynalea  Whiteman Pena https://leg.mt.gov//legislator-information/roster/individual/6828
# Fetching Kathy  Whitman https://leg.mt.gov//legislator-information/roster/individual/6929
# Fetching Jonathan  Windy Boy https://leg.mt.gov//legislator-information/roster/individual/6857
# Fetching Katie  Zolnikov https://leg.mt.gov//legislator-information/roster/individual/6846
# File written

# %%
# comobine
init = pd.read_json('process/lawmakers-init.json', orient='records')
contact = pd.read_json('process/contact-info.json', orient='records')
df = init.merge(contact, on='name')
df.to_json('process/lawmakers.json', orient='records')

# %%
init.to_json('process/lawmakers.json', orient='records')

# %%
# get_lawmaker(roster[0])

# %%
year = '2021'
details = []
for lawmaker in roster:
    # Temporary fix — skip Kathy Whitman w/ broken page
    if lawmaker['url'] != 'https://leg.mt.gov//legislator-information/roster/individual/6929':
        results = get_lawmaker(lawmaker)
        details.append(results)
    
with open('process/lawmakers.json', 'w') as f:
    stringed = json.dumps(details, indent=4)
    f.write(stringed)
    print('File written')
# Out:
# Fetching Kim  Abbott https://leg.mt.gov//legislator-information/roster/individual/6872
# --Image written to images/Kim-Abbott-2021.png
# Fetching Fred  Anderson https://leg.mt.gov//legislator-information/roster/individual/6898
# --Image written to images/Fred-Anderson-2021.png
# Fetching Duane  Ankney https://leg.mt.gov//legislator-information/roster/individual/6810
# --Image written to images/Carl-Glimm-2021.png
# Fetching Sharon  Greef https://leg.mt.gov//legislator-information/roster/individual/6855
# --Image written to images/Sharon-Greef-2021.png
# Fetching Jen  Gross https://leg.mt.gov//legislator-information/roster/individual/6881
# --Image written to images/Jen-Gross-2021.png
# Fetching Steve  Gunderson https://leg.mt.gov//legislator-information/roster/individual/6888
# --Image written to images/Steve-Gunderson-2021.png
# Fetching Jim  Hamilton https://leg.mt.gov//legislator-information/roster/individual/6830
# --Image written to images/Jim-Hamilton-2021.png
# Fetching Derek  Harvey https://leg.mt.gov//legislator-information/roster/individual/6866
# --Image written to images/Derek-Harvey-2021.png
# Fetching Donavon  Hawk https://leg.mt.gov//legislator-information/roster/individual/6867
# --Image written to images/Donavon-Hawk-2021.png
# Fetching Denise  Hayman https://leg.mt.gov//legislator-information/roster/individual/6831
# --Image written to images/Denise-Hayman-2021.png
# Fetching Greg  Hertz https://leg.mt.gov//legislator-information/roster/individual/6818
# --Image written to images/Greg-Hertz-2021.png
# Fetching Ed  Hill https://leg.mt.gov//legislator-information/roster/individual/6905
# --Image written to images/Ed-Hill-2021.png
# Fetching Steve  Hinebauch https://leg.mt.gov//legislator-information/roster/individual/6934
# --Image written to images/Steve-Hinebauch-2021.png
# Fetching Jedediah  Hinkle https://leg.mt.gov//legislator-information/roster/individual/6919
# --Image written to images/Jedediah-Hinkle-2021.png
# Fetching Caleb  Hinkle https://leg.mt.gov//legislator-information/roster/individual/6920
# --Image written to images/Caleb-Hinkle-2021.png
# Fetching Kenneth  Holmlund https://leg.mt.gov//legislator-information/roster/individual/6844
# --Image written to images/Kenneth-Holmlund-2021.png
# Fetching Mike  Hopkins https://leg.mt.gov//legislator-information/roster/individual/6927
# --Image written to images/Mike-Hopkins-2021.png
# Fetching Brian  Hoven https://leg.mt.gov//legislator-information/roster/individual/6807
# --Image written to images/Brian-Hoven-2021.png
# Fetching David  Howard https://leg.mt.gov//legislator-information/roster/individual/6813
# --Image written to images/David-Howard-2021.png
# Fetching Tom  Jacobson https://leg.mt.gov//legislator-information/roster/individual/6794
# --Image written to images/Tom-Jacobson-2021.png
# Fetching Llew  Jones https://leg.mt.gov//legislator-information/roster/individual/6837
# --Image written to images/Llew-Jones-2021.png
# Fetching Jessica  Karjala https://leg.mt.gov//legislator-information/roster/individual/6859
# --Image written to images/Jessica-Karjala-2021.png
# Fetching Doug  Kary https://leg.mt.gov//legislator-information/roster/individual/6811
# --Image written to images/Doug-Kary-2021.png
# Fetching Josh  Kassmier https://leg.mt.gov//legislator-information/roster/individual/6838
# --Image written to images/Josh-Kassmier-2021.png
# Fetching Jim  Keane https://leg.mt.gov//legislator-information/roster/individual/6865
# --Image written to images/Jim-Keane-2021.png
# Fetching Bob  Keenan https://leg.mt.gov//legislator-information/roster/individual/6805
# --Image written to images/Bob-Keenan-2021.png
# Fetching Kathy  Kelker https://leg.mt.gov//legislator-information/roster/individual/6858
# --Image written to images/Kathy-Kelker-2021.png
# Fetching Connie  Keogh https://leg.mt.gov//legislator-information/roster/individual/6876
# --Image written to images/Connie-Keogh-2021.png
# Fetching Scot  Kerns https://leg.mt.gov//legislator-information/roster/individual/6901
# --Image written to images/Scot-Kerns-2021.png
# Fetching Emma  Kerr-Carpenter https://leg.mt.gov//legislator-information/roster/individual/6860
# --Image written to images/Emma-Kerr-Carpenter-2021.png
# Fetching Rhonda  Knudsen https://leg.mt.gov//legislator-information/roster/individual/6841
# --Image written to images/Rhonda-Knudsen-2021.png
# Fetching Casey  Knudsen https://leg.mt.gov//legislator-information/roster/individual/6840
# --Image written to images/Casey-Knudsen-2021.png
# Fetching Kelly  Kortum https://leg.mt.gov//legislator-information/roster/individual/6864
# --Image written to images/Kelly-Kortum-2021.png
# Fetching Mike  Lang https://leg.mt.gov//legislator-information/roster/individual/6821
# --Image written to images/Mike-Lang-2021.png
# Fetching Dennis  Lenz https://leg.mt.gov//legislator-information/roster/individual/6847
# --Image written to images/Dennis-Lenz-2021.png
# Fetching Brandon  Ler https://leg.mt.gov//legislator-information/roster/individual/6842
# --Image written to images/Brandon-Ler-2021.png
# Fetching Denley  Loge https://leg.mt.gov//legislator-information/roster/individual/6836
# --Image written to images/Denley-Loge-2021.png
# Fetching Ryan  Lynch https://leg.mt.gov//legislator-information/roster/individual/6883
# --Image written to images/Ryan-Lynch-2021.png
# Fetching Marty  Malone https://leg.mt.gov//legislator-information/roster/individual/6917
# --Image written to images/Marty-Malone-2021.png
# Fetching Theresa  Manzella https://leg.mt.gov//legislator-information/roster/individual/6939
# --Image written to images/Theresa-Manzella-2021.png
# Fetching Marilyn  Marler https://leg.mt.gov//legislator-information/roster/individual/6875
# --Image written to images/Marilyn-Marler-2021.png
# Fetching Ron  Marshall https://leg.mt.gov//legislator-information/roster/individual/6926
# --Image written to images/Ron-Marshall-2021.png
# Fetching Edie  McClafferty https://leg.mt.gov//legislator-information/roster/individual/6884
# --Image written to images/Edie-McClafferty-2021.png
# Fetching Tom  McGillvray https://leg.mt.gov//legislator-information/roster/individual/6822
# --Image written to images/Tom-McGillvray-2021.png
# Fetching Wendy  McKamey https://leg.mt.gov//legislator-information/roster/individual/6897
# --Image written to images/Wendy-McKamey-2021.png
# Fetching Mary  McNally https://leg.mt.gov//legislator-information/roster/individual/6796
# --Image written to images/Mary-McNally-2021.png
# Fetching Bill  Mercer https://leg.mt.gov//legislator-information/roster/individual/6911
# --Image written to images/Bill-Mercer-2021.png
# Fetching Braxton  Mitchell https://leg.mt.gov//legislator-information/roster/individual/6890
# --Image written to images/Braxton-Mitchell-2021.png
# Fetching Brad  Molnar https://leg.mt.gov//legislator-information/roster/individual/6823
# --Image written to images/Brad-Molnar-2021.png
# Fetching Terry  Moore https://leg.mt.gov//legislator-information/roster/individual/6915
# --Image written to images/Terry-Moore-2021.png
# Fetching Shane  Morigeau https://leg.mt.gov//legislator-information/roster/individual/6942
# --Image written to images/Shane-Morigeau-2021.png
# Fetching Fiona  Nave https://leg.mt.gov//legislator-information/roster/individual/6850
# --Image written to images/Fiona-Nave-2021.png
# Fetching Mark  Noland https://leg.mt.gov//legislator-information/roster/individual/6893
# --Image written to images/Mark-Noland-2021.png
# Fetching Sara  Novak https://leg.mt.gov//legislator-information/roster/individual/6868
# --Image written to images/Sara-Novak-2021.png
# Fetching Shannon  O'Brien https://leg.mt.gov//legislator-information/roster/individual/6887
# --Image written to images/Shannon-O'Brien-2021.png
# Fetching Andrea  Olsen https://leg.mt.gov//legislator-information/roster/individual/6941
# --Image written to images/Andrea-Olsen-2021.png
# Fetching Ryan  Osmundson https://leg.mt.gov//legislator-information/roster/individual/6820
# --Image written to images/Ryan-Osmundson-2021.png
# Fetching Jimmy  Patelis https://leg.mt.gov//legislator-information/roster/individual/6914
# --Image written to images/Jimmy-Patelis-2021.png
# Fetching Bob  Phalen https://leg.mt.gov//legislator-information/roster/individual/6843
# --Image written to images/Bob-Phalen-2021.png
# Fetching JP  Pomnichowski https://leg.mt.gov//legislator-information/roster/individual/6798
# --Image written to images/JP-Pomnichowski-2021.png
# Fetching Christopher  Pope https://leg.mt.gov//legislator-information/roster/individual/6882
# --Image written to images/Chris-Pope-2021.png
# Fetching Brian  Putnam https://leg.mt.gov//legislator-information/roster/individual/6834
# --Image written to images/Brian-Putnam-2021.png
# Fetching Joe  Read https://leg.mt.gov//legislator-information/roster/individual/6928
# --Image written to images/Joe-Read-2021.png
# Fetching Keith  Regier https://leg.mt.gov//legislator-information/roster/individual/6932
# --Image written to images/Keith-Regier-2021.png
# Fetching Matt  Regier https://leg.mt.gov//legislator-information/roster/individual/6832
# --Image written to images/Matt-Regier-2021.png
# Fetching Amy  Regier https://leg.mt.gov//legislator-information/roster/individual/6891
# --Image written to images/Amy-Regier-2021.png
# Fetching Linda  Reksten https://leg.mt.gov//legislator-information/roster/individual/6894
# --Image written to images/Linda-Reksten-2021.png
# Fetching Vince  Ricci https://leg.mt.gov//legislator-information/roster/individual/6848
# --Image written to images/Vince-Ricci-2021.png
# Fetching Tyson  Running Wolf https://leg.mt.gov//legislator-information/roster/individual/6826
# --Image written to images/Tyson-Running-Wolf-2021.png
# Fetching Walt  Sales https://leg.mt.gov//legislator-information/roster/individual/6824
# --Image written to images/Walt-Sales-2021.png
# Fetching Dan  Salomon https://leg.mt.gov//legislator-information/roster/individual/6940
# --Image written to images/Dan-Salomon-2021.png
# Fetching Diane  Sands https://leg.mt.gov//legislator-information/roster/individual/6801
# --Image written to images/Diane-Sands-2021.png
# Fetching Jerry  Schillinger https://leg.mt.gov//legislator-information/roster/individual/6907
# --Image written to images/Jerry-Schillinger-2021.png
# Fetching Kerri  Seekins-Crowe https://leg.mt.gov//legislator-information/roster/individual/6909
# --Image written to images/Kerri-Seekins-Crowe-2021.png
# Fetching Lola  Sheldon-Galloway https://leg.mt.gov//legislator-information/roster/individual/6900
# --Image written to images/Lola-Sheldon-Galloway-2021.png
# Fetching Derek  Skees https://leg.mt.gov//legislator-information/roster/individual/6835
# --Image written to images/Derek-Skees-2021.png
# Fetching Jason  Small https://leg.mt.gov//legislator-information/roster/individual/6935
# --Image written to images/Jason-Small-2021.png
# Fetching Cary  Smith https://leg.mt.gov//legislator-information/roster/individual/6812
# --Image written to images/Cary-Smith-2021.png
# Fetching Frank  Smith https://leg.mt.gov//legislator-information/roster/individual/6827
# --Image written to images/Frank-Smith-2021.png
# Fetching Ed  Stafman https://leg.mt.gov//legislator-information/roster/individual/6862
# --Image written to images/Ed-Stafman-2021.png
# Fetching Sharon  Stewart Peregoy https://leg.mt.gov//legislator-information/roster/individual/6829
# --Image written to images/Sharon-Stewart-Peregoy-2021.png
# Fetching Mallerie  Stromswold https://leg.mt.gov//legislator-information/roster/individual/6912
# --Image written to images/Mallerie-Stromswold-2021.png
# Fetching Katie  Sullivan https://leg.mt.gov//legislator-information/roster/individual/6874
# --Image written to images/Katie-Sullivan-2021.png
# Fetching Mark  Sweeney https://leg.mt.gov//legislator-information/roster/individual/6885
# --Image written to images/Mark-Sweeney-2021.png
# Fetching Russ  Tempel https://leg.mt.gov//legislator-information/roster/individual/6808
# --Image written to images/Russ-Tempel-2021.png
# Fetching Danny  Tenenbaum https://leg.mt.gov//legislator-information/roster/individual/6878
# --Image written to images/Danny-Tenenbaum-2021.png
# Fetching Mark  Thane https://leg.mt.gov//legislator-information/roster/individual/6880
# --Image written to images/Mark-Thane-2021.png
# Fetching Jeremy  Trebas https://leg.mt.gov//legislator-information/roster/individual/6904
# --Image written to images/Jeremy-Trebas-2021.png
# Fetching Brad  Tschida https://leg.mt.gov//legislator-information/roster/individual/6930
# --Image written to images/Brad-Tschida-2021.png
# Fetching Barry  Usher https://leg.mt.gov//legislator-information/roster/individual/6908
# --Image written to images/Barry-Usher-2021.png
# Fetching Gordon  Vance https://leg.mt.gov//legislator-information/roster/individual/6815
# --Image written to images/Gordon-Vance-2021.png
# Fetching Sue  Vinton https://leg.mt.gov//legislator-information/roster/individual/6849
# --Image written to images/Sue-Vinton-2021.png
# Fetching Kenneth  Walsh https://leg.mt.gov//legislator-information/roster/individual/6921
# --Image written to images/Kenneth-Walsh-2021.png
# Fetching Marvin  Weatherwax https://leg.mt.gov//legislator-information/roster/individual/6825
# --Image written to images/Marvin-Weatherwax-2021.png
# Fetching Susan  Webber https://leg.mt.gov//legislator-information/roster/individual/6793
# --Image written to images/Susan-Webber-2021.png
# Fetching Jeff  Welborn https://leg.mt.gov//legislator-information/roster/individual/6937
# --Image written to images/Jeff-Welborn-2021.png
# Fetching Tom  Welch https://leg.mt.gov//legislator-information/roster/individual/6853
# --Image written to images/Tom-Welch-2021.png
# Fetching Rynalea  Whiteman Pena https://leg.mt.gov//legislator-information/roster/individual/6828
# --Image written to images/Rynalea-Whiteman-Pena-2021.png
# Fetching Jonathan  Windy Boy https://leg.mt.gov//legislator-information/roster/individual/6857
# --Image written to images/Jonathan-Windy-Boy-2021.png
# Fetching Katie  Zolnikov https://leg.mt.gov//legislator-information/roster/individual/6846
# --Image written to images/Katie-Zolnikov-2021.png
# File written
